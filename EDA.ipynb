# %% [markdown]
# # Forecasting Time Series with optimization based models

# %% [markdown]
# The time series repository used to evaluate the models can be found here: http://sites.labic.icmc.usp.br/icmc_tspr/index.php/datasets

# %% [markdown]
# The preprocessing procedure was based on : https://www.researchgate.net/publication/320321525_Forecasting_Across_Time_Series_Databases_using_Long_Short-Term_Memory_Networks_on_Groups_of_Similar_Series. Items 3.4 to 3.7 with some small changes.

# %% [markdown]
# The models tested were:
# - Linear Support Vector Machine (https://scikit-learn.org/stable/modules/svm.html#mathematical-formulation - item 1.4.7.5)
# - Bayesian Regression (https://mml-book.github.io/book/mml-book.pdf - pages 303 to 313)
#
# Both with and without applying the STL decomposition, the other pipeline components like rolling window, and local de-trending are kept fixed.
#
# And the baselines were:
# - auto.arima
# - ets

# %% [markdown]
# ## Assumptions we'll make

# %% [markdown]
# - Seasonal pattern doesn't change over time;
# - STL residuals are white noise;
# - The time series comes from an autoregressive process.

# %% [markdown]
# ## Assumptions we'll relax

# %% [markdown]
# - The training set is independent and identically distributed according to a fixed distribution $\rho$ on $\mathcal{Y}^p \times \mathcal{Y}$, where $p$ is the autoregressive order.

# %% [markdown]
# ## Evaluation procedure

# %% [markdown]
# We splitted each time series using a holdout technique, 95% to train e 5% to test. The functions $\textit{ets}$, $\textit{auto.arima}$ and $\textit{forecast}$ from the $\textit{forecast}$ package were used to obtain the predictions for the baseline models. On the other hand, the svm and the bayesian regression were trained using the following:

# %% [markdown]
#     0. function evaluation(model:svm or bayesian, y:time series, decompose:bool):
#     1.     split y into train and test
#     2.     apply log to train
#     3.     if decompose is True:
#     4.         decompose train using STL
#     5.         fit naive forecaster on seasonal component
#     6.         split (trend + residual) into train* and validation
#     7.         apply grid search on (train*, validation)
#     8.         forecast using model initialized with the best parameters found
#     9.         exponentiate the forecasted values
#     10.        return test and forecasted values
#     11.   else:
#     12.        split train into train* and validation
#     13.        repeat lines 7. to 10.

# %% [markdown]
# The search space for the SVM was the same used in here: https://www.researchgate.net/publication/330742498_Evaluation_of_statistical_and_machine_learning_models_for_time_series_prediction_Identifying_the_state-of-the-art_and_the_best_conditions_for_the_use_of_each_model, page 21. Moreover, the bayesian regression is able to optimize its own parameters like is described here : https://scikit-learn.org/stable/modules/linear_model.html#bayesian-regression.

# %% [markdown]
# We used the mean absolute error (MAE) to compare the models, now we'll analyse the results

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv("results.csv", index_col=0)
df.head()
# Out:
#         category    autoets  autoarima  linear_svr  stl_linear_svr  \
# 0  deterministic  73.896820   9.345932    0.118581    1.708678e-12
# 1  deterministic  73.896820  49.189988    0.203931    1.969832e-01
# 2  deterministic  73.896820  48.952778    2.767953    4.987801e-01
# 3  deterministic   7.331475   3.425046    0.625135    4.626489e+00
# 4  deterministic   6.647874   7.445414    0.296796    4.533904e+00
#
#    bayesian_ridge  stl_bayesian_ridge residuals_are_independent
# 0        0.000034        1.708678e-12                     False
# 1        0.053057        1.541884e-01                     False
# 2        3.314283        4.937540e-01                     False
# 3        0.616375        4.694656e+00                     False
# 4        0.556557        4.600456e+00                     False

# %% [markdown]
# The column category tells us the type of the time series considered, the columns 2 to 7 are the MAE's of each model and the last column indicates wheter the residuals from the STL decomposition are white noise using the Ljung-Box test: https://www.statsmodels.org/stable/generated/statsmodels.stats.diagnostic.acorr_ljungbox.html

# %% [markdown]
# In order to make the analysis easier, we'll rank the models from best (column 1) to worst (column 6)

# %%
def rank(df:pd.DataFrame)->pd.DataFrame:
    rank_row = lambda row:pd.Series.sort_values(row[1:-1]).index.tolist()
    return pd.DataFrame(
        [rank_row(row)+[row[-1]] for i, row in df.iterrows()], 
        columns=["1", "2", "3", "4", "5", "6", "residuals_are_independent"])

# %% [markdown]
# ### Deterministic data

# %%
rank(df[df.category=="deterministic"])
# Out:
#                      1                   2                   3  \
# 0       stl_linear_svr  stl_bayesian_ridge      bayesian_ridge
# 1       bayesian_ridge  stl_bayesian_ridge      stl_linear_svr
# 2   stl_bayesian_ridge      stl_linear_svr          linear_svr
# 3       bayesian_ridge          linear_svr           autoarima
# 4           linear_svr      bayesian_ridge      stl_linear_svr
# 5           linear_svr      bayesian_ridge      stl_linear_svr
# 6       bayesian_ridge          linear_svr  stl_bayesian_ridge
# 7       bayesian_ridge          linear_svr           autoarima
# 8           linear_svr      bayesian_ridge           autoarima
# 9       bayesian_ridge          linear_svr           autoarima
# 10      bayesian_ridge          linear_svr  stl_bayesian_ridge
# 11      bayesian_ridge          linear_svr  stl_bayesian_ridge
# 12      stl_linear_svr  stl_bayesian_ridge      bayesian_ridge
# 13      bayesian_ridge      stl_linear_svr  stl_bayesian_ridge
# 14      bayesian_ridge          linear_svr      stl_linear_svr
# 15  stl_bayesian_ridge      stl_linear_svr             autoets
# 16  stl_bayesian_ridge      stl_linear_svr      bayesian_ridge
#
#                      4                   5               6  \
# 0           linear_svr           autoarima         autoets
# 1           linear_svr           autoarima         autoets
# 2       bayesian_ridge           autoarima         autoets
# 3       stl_linear_svr  stl_bayesian_ridge         autoets
# 4   stl_bayesian_ridge             autoets       autoarima
# 5   stl_bayesian_ridge             autoets       autoarima
# 6              autoets           autoarima  stl_linear_svr
# 7   stl_bayesian_ridge             autoets  stl_linear_svr
# 8   stl_bayesian_ridge      stl_linear_svr         autoets
# 9   stl_bayesian_ridge      stl_linear_svr         autoets
# 10      stl_linear_svr           autoarima         autoets
# 11      stl_linear_svr           autoarima         autoets
# 12          linear_svr           autoarima         autoets
# 13          linear_svr           autoarima         autoets
# 14           autoarima  stl_bayesian_ridge         autoets
# 15      bayesian_ridge          linear_svr       autoarima
# 16          linear_svr           autoarima         autoets
#
#     residuals_are_independent
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# 5                       False
# 6                       False
# 7                       False
# 8                       False
# 9                       False
# 10                      False
# 11                      False
# 12                      False
# 13                      False
# 14                      False
# 15                      False
# 16                       True

# %% [markdown]
# When it comes to deterministic time series the machine learning models tend to outperform both the baseline and the STL framework, it's worth to notice the residuals are not independent in almost all datasets.

# %% [markdown]
# ### Stochastic data

# %%
rank(df[df.category=="stochastic"])
# Out:
#                  1               2                   3                   4  \
# 0        autoarima         autoets      stl_linear_svr  stl_bayesian_ridge
# 1   bayesian_ridge      linear_svr           autoarima  stl_bayesian_ridge
# 2          autoets      linear_svr      bayesian_ridge  stl_bayesian_ridge
# 3          autoets      linear_svr      bayesian_ridge      stl_linear_svr
# 4   stl_linear_svr       autoarima  stl_bayesian_ridge             autoets
# 5        autoarima         autoets      stl_linear_svr  stl_bayesian_ridge
# 6       linear_svr  bayesian_ridge      stl_linear_svr  stl_bayesian_ridge
# 7        autoarima      linear_svr      bayesian_ridge  stl_bayesian_ridge
# 8       linear_svr  bayesian_ridge      stl_linear_svr  stl_bayesian_ridge
# 9       linear_svr  bayesian_ridge      stl_linear_svr  stl_bayesian_ridge
# 10      linear_svr  bayesian_ridge      stl_linear_svr  stl_bayesian_ridge
# 11      linear_svr  bayesian_ridge      stl_linear_svr  stl_bayesian_ridge
# 12       autoarima      linear_svr  stl_bayesian_ridge      bayesian_ridge
# 13      linear_svr  stl_linear_svr      bayesian_ridge  stl_bayesian_ridge
# 14  bayesian_ridge      linear_svr      stl_linear_svr  stl_bayesian_ridge
#
#                      5           6  residuals_are_independent
# 0       bayesian_ridge  linear_svr                       True
# 1       stl_linear_svr     autoets                       True
# 2       stl_linear_svr   autoarima                      False
# 3   stl_bayesian_ridge   autoarima                      False
# 4       bayesian_ridge  linear_svr                       True
# 5       bayesian_ridge  linear_svr                       True
# 6            autoarima     autoets                       True
# 7       stl_linear_svr     autoets                       True
# 8            autoarima     autoets                       True
# 9            autoarima     autoets                       True
# 10           autoarima     autoets                       True
# 11           autoarima     autoets                       True
# 12      stl_linear_svr     autoets                      False
# 13           autoarima     autoets                      False
# 14           autoarima     autoets                      False

# %% [markdown]
# Here, although the majority of the time series could have had its components decomposed successfully, the STL failed.

# %% [markdown]
# ### Chaotic data

# %%
rank(df[df.category=="chaotic"])
# Out:
#                 1               2                   3                   4  \
# 0      linear_svr  bayesian_ridge  stl_bayesian_ridge      stl_linear_svr
# 1         autoets       autoarima      bayesian_ridge          linear_svr
# 2       autoarima  stl_linear_svr  stl_bayesian_ridge          linear_svr
# 3      linear_svr  bayesian_ridge           autoarima  stl_bayesian_ridge
# 4       autoarima  bayesian_ridge          linear_svr      stl_linear_svr
# 5  bayesian_ridge         autoets          linear_svr  stl_bayesian_ridge
# 6       autoarima      linear_svr      bayesian_ridge             autoets
# 7      linear_svr  bayesian_ridge           autoarima  stl_bayesian_ridge
#
#                     5                   6  residuals_are_independent
# 0             autoets           autoarima                      False
# 1  stl_bayesian_ridge      stl_linear_svr                      False
# 2      bayesian_ridge             autoets                      False
# 3      stl_linear_svr             autoets                      False
# 4  stl_bayesian_ridge             autoets                      False
# 5      stl_linear_svr           autoarima                      False
# 6      stl_linear_svr  stl_bayesian_ridge                      False
# 7      stl_linear_svr             autoets                      False

# %% [markdown]
# We can spot no pattern at all, the STL decomposition is not trustworthy.

# %% [markdown]
# ### Daily

# %%
rank(df[df.category=="daily"])
# Out:
#                      1                   2                   3  \
# 0       stl_linear_svr  stl_bayesian_ridge      bayesian_ridge
# 1            autoarima      bayesian_ridge          linear_svr
# 2              autoets           autoarima      bayesian_ridge
# 3            autoarima             autoets      stl_linear_svr
# 4              autoets           autoarima      stl_linear_svr
# 5   stl_bayesian_ridge      stl_linear_svr             autoets
# 6              autoets           autoarima      stl_linear_svr
# 7            autoarima  stl_bayesian_ridge      stl_linear_svr
# 8            autoarima  stl_bayesian_ridge      stl_linear_svr
# 9            autoarima      bayesian_ridge          linear_svr
# 10           autoarima  stl_bayesian_ridge      stl_linear_svr
# 11  stl_bayesian_ridge      stl_linear_svr          linear_svr
# 12           autoarima  stl_bayesian_ridge      stl_linear_svr
# 13             autoets          linear_svr      bayesian_ridge
# 14      bayesian_ridge          linear_svr  stl_bayesian_ridge
# 15      bayesian_ridge          linear_svr  stl_bayesian_ridge
# 16             autoets           autoarima      stl_linear_svr
# 17           autoarima             autoets  stl_bayesian_ridge
# 18             autoets           autoarima      bayesian_ridge
# 19          linear_svr             autoets      bayesian_ridge
# 20          linear_svr      bayesian_ridge             autoets
#
#                      4                   5                   6  \
# 0           linear_svr             autoets           autoarima
# 1              autoets  stl_bayesian_ridge      stl_linear_svr
# 2           linear_svr  stl_bayesian_ridge      stl_linear_svr
# 3   stl_bayesian_ridge          linear_svr      bayesian_ridge
# 4   stl_bayesian_ridge      bayesian_ridge          linear_svr
# 5            autoarima      bayesian_ridge          linear_svr
# 6   stl_bayesian_ridge      bayesian_ridge          linear_svr
# 7       bayesian_ridge          linear_svr             autoets
# 8              autoets          linear_svr      bayesian_ridge
# 9   stl_bayesian_ridge      stl_linear_svr             autoets
# 10          linear_svr      bayesian_ridge             autoets
# 11      bayesian_ridge           autoarima             autoets
# 12      bayesian_ridge          linear_svr             autoets
# 13  stl_bayesian_ridge      stl_linear_svr           autoarima
# 14      stl_linear_svr             autoets           autoarima
# 15      stl_linear_svr           autoarima             autoets
# 16  stl_bayesian_ridge      bayesian_ridge          linear_svr
# 17      stl_linear_svr      bayesian_ridge          linear_svr
# 18          linear_svr      stl_linear_svr  stl_bayesian_ridge
# 19      stl_linear_svr  stl_bayesian_ridge           autoarima
# 20           autoarima  stl_bayesian_ridge      stl_linear_svr
#
#     residuals_are_independent
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# 5                        True
# 6                       False
# 7                       False
# 8                       False
# 9                       False
# 10                      False
# 11                      False
# 12                      False
# 13                      False
# 14                      False
# 15                      False
# 16                      False
# 17                      False
# 18                      False
# 19                      False
# 20                       True

# %% [markdown]
# The STL wasn't able to decompose the daily time series, probably due to the presence of multiple hidden patterns. Thus, we cannot guarantee that our framework can be applied successfully.

# %% [markdown]
# ### Monthly data

# %%
rank(df[df.category=="monthly"])
# Out:
#                      1                   2                   3  \
# 0       stl_linear_svr  stl_bayesian_ridge             autoets
# 1              autoets      stl_linear_svr  stl_bayesian_ridge
# 2              autoets  stl_bayesian_ridge      stl_linear_svr
# 3              autoets  stl_bayesian_ridge      stl_linear_svr
# 4            autoarima             autoets      stl_linear_svr
# 5              autoets          linear_svr           autoarima
# 6              autoets      stl_linear_svr  stl_bayesian_ridge
# 7              autoets      stl_linear_svr  stl_bayesian_ridge
# 8              autoets      bayesian_ridge          linear_svr
# 9            autoarima             autoets      bayesian_ridge
# 10      bayesian_ridge          linear_svr             autoets
# 11  stl_bayesian_ridge      stl_linear_svr           autoarima
# 12          linear_svr           autoarima      bayesian_ridge
# 13             autoets          linear_svr      bayesian_ridge
# 14             autoets           autoarima      stl_linear_svr
# 15             autoets          linear_svr      bayesian_ridge
# 16             autoets      stl_linear_svr  stl_bayesian_ridge
# 17             autoets      bayesian_ridge          linear_svr
# 18             autoets           autoarima      bayesian_ridge
# 19          linear_svr      bayesian_ridge             autoets
# 20           autoarima      stl_linear_svr  stl_bayesian_ridge
# 21             autoets           autoarima  stl_bayesian_ridge
# 22             autoets      stl_linear_svr  stl_bayesian_ridge
# 23          linear_svr             autoets      bayesian_ridge
# 24             autoets      stl_linear_svr  stl_bayesian_ridge
# 25      stl_linear_svr  stl_bayesian_ridge           autoarima
# 26             autoets      stl_linear_svr  stl_bayesian_ridge
# 27  stl_bayesian_ridge      stl_linear_svr           autoarima
# 28      stl_linear_svr  stl_bayesian_ridge             autoets
# 29      stl_linear_svr  stl_bayesian_ridge             autoets
#
#                      4                   5                   6  \
# 0            autoarima          linear_svr      bayesian_ridge
# 1            autoarima      bayesian_ridge          linear_svr
# 2            autoarima      bayesian_ridge          linear_svr
# 3       bayesian_ridge          linear_svr           autoarima
# 4   stl_bayesian_ridge          linear_svr      bayesian_ridge
# 5       bayesian_ridge      stl_linear_svr  stl_bayesian_ridge
# 6           linear_svr      bayesian_ridge           autoarima
# 7           linear_svr      bayesian_ridge           autoarima
# 8            autoarima      stl_linear_svr  stl_bayesian_ridge
# 9           linear_svr      stl_linear_svr  stl_bayesian_ridge
# 10           autoarima  stl_bayesian_ridge      stl_linear_svr
# 11      bayesian_ridge          linear_svr             autoets
# 12             autoets      stl_linear_svr  stl_bayesian_ridge
# 13           autoarima  stl_bayesian_ridge      stl_linear_svr
# 14  stl_bayesian_ridge      bayesian_ridge          linear_svr
# 15  stl_bayesian_ridge      stl_linear_svr           autoarima
# 16           autoarima      bayesian_ridge          linear_svr
# 17      stl_linear_svr  stl_bayesian_ridge           autoarima
# 18          linear_svr  stl_bayesian_ridge      stl_linear_svr
# 19           autoarima  stl_bayesian_ridge      stl_linear_svr
# 20          linear_svr      bayesian_ridge             autoets
# 21          linear_svr      bayesian_ridge      stl_linear_svr
# 22          linear_svr      bayesian_ridge           autoarima
# 23           autoarima  stl_bayesian_ridge      stl_linear_svr
# 24           autoarima          linear_svr      bayesian_ridge
# 25             autoets          linear_svr      bayesian_ridge
# 26           autoarima          linear_svr      bayesian_ridge
# 27             autoets          linear_svr      bayesian_ridge
# 28           autoarima      bayesian_ridge          linear_svr
# 29           autoarima      bayesian_ridge          linear_svr
#
#     residuals_are_independent
# 0                        True
# 1                        True
# 2                       False
# 3                        True
# 4                       False
# 5                       False
# 6                       False
# 7                       False
# 8                       False
# 9                       False
# 10                      False
# 11                      False
# 12                       True
# 13                      False
# 14                      False
# 15                      False
# 16                       True
# 17                       True
# 18                       True
# 19                       True
# 20                      False
# 21                       True
# 22                      False
# 23                      False
# 24                       True
# 25                       True
# 26                       True
# 27                       True
# 28                       True
# 29                       True

# %% [markdown]
# Looking at the datasets in which the residuals are white noise we can spot that: in 10 out of 15 samples the STL-SVM had a lower error in comparison with the raw SVM estimator and moreover, in 11 out 15 the STL-BAYESIAN also was better than the BAYESIAN. Finally, we can see that the STL framework, even improving the accuracy, it's not enough to be better than the exponential smoothing and arima models.

# %% [markdown]
# ### Other

# %%
rank(pd.concat([df[df.category=="annual"], df.iloc[-4:,:]]))
# Out:
#                 1                   2               3                   4  \
# 0         autoets           autoarima      linear_svr      bayesian_ridge
# 1      linear_svr      bayesian_ridge       autoarima      stl_linear_svr
# 2      linear_svr      stl_linear_svr  bayesian_ridge  stl_bayesian_ridge
# 3  stl_linear_svr  stl_bayesian_ridge       autoarima             autoets
# 4         autoets      bayesian_ridge      linear_svr           autoarima
# 5       autoarima          linear_svr  bayesian_ridge             autoets
# 6       autoarima      bayesian_ridge      linear_svr             autoets
#
#                     5                   6 residuals_are_independent
# 0      stl_linear_svr  stl_bayesian_ridge                      True
# 1  stl_bayesian_ridge             autoets                     False
# 2           autoarima             autoets                       NaN
# 3      bayesian_ridge          linear_svr                      True
# 4  stl_bayesian_ridge      stl_linear_svr                     False
# 5  stl_bayesian_ridge      stl_linear_svr                     False
# 6      stl_linear_svr  stl_bayesian_ridge                     False

# %% [markdown]
# Not enough data to conclude something.
